# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
from google.colab import files
from matplotlib import pyplot as plt
from PIL import Image

img = cv2.imread('/content/drive/MyDrive/blending_logo_for_blue_car/input_frames/frame1.jpg')
mask = cv2.imread('/content/drive/MyDrive/blending_logo_for_blue_car/mask.png', cv2.IMREAD_GRAYSCALE)

inpainted_img = cv2.inpaint(img, mask, 25, cv2.INPAINT_NS)
cv2.imwrite("/content/drive/MyDrive/blending_logo_for_blue_car/inpainted_img.jpg", inpainted_img)

cv2_imshow(inpainted_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np

video_path = '/content/drive/MyDrive/blending_logo_for_blue_car/11s trimmed.mp4'
mask_path = '/content/drive/MyDrive/blending_logo_for_blue_car/mask.png'

cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

fourcc = cv2.VideoWriter_fourcc(*'MP4V')
output_path = '/content/drive/MyDrive/blending_logo_for_blue_car/inpainted_video.mp4'
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()

    if not ret:
        break


    inpainted_frame = cv2.inpaint(frame, mask, 15, cv2.INPAINT_NS)


    out.write(inpainted_frame)


cap.release()
out.release()
